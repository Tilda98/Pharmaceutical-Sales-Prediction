# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Import requored libraries
import pandas as pd
import numpy as np
import holidays
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Stores dataset
store_df = pd.read_csv('../data/store.csv', na_values=['?', None])
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
# Test sales dataset
test_df = pd.read_csv('../data/test.csv', na_values=['?', None])
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
# Train sales dataset
train_df = pd.read_csv('../data/train.csv', na_values=['?', None])
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Merging train and stores datasets
train_store = pd.merge(train_df, store_df, how = 'left', on = "Store")
train_store
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# Merging test and store dataset
test_store = pd.merge(test_df, store_df, how = 'left', on = "Store")
test_store
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0         c          a               1270.0
# ...

# %%
train_store.sort_values(["Store","Date"], ignore_index=True, inplace=True)
test_store.sort_values(["Store","Date"], ignore_index=True, inplace=True)

for dataset in (train_store,test_store):
    dataset['Date'] = pd.to_datetime(dataset['Date'])
    dataset['Day'] = dataset.Date.dt.day
    dataset['Month'] = dataset.Date.dt.month
    dataset['Year'] = dataset.Date.dt.year
    dataset['DayOfYear'] = dataset.Date.dt.dayofyear
    dataset['WeekOfYear'] = dataset.Date.dt.weekofyear
    dataset.set_index('Date', inplace=True)

# %%
# Column names
test_store.columns.tolist()
# Out:
# ['Id',
#  'Store',
#  'DayOfWeek',
#  'Open',
#  'Promo',
#  'StateHoliday',
#  'SchoolHoliday',
#  'StoreType',
#  'Assortment',
#  'CompetitionDistance',
#  'CompetitionOpenSinceMonth',
#  'CompetitionOpenSinceYear',
#  'Promo2',
#  'Promo2SinceWeek',
#  'Promo2SinceYear',
#  'PromoInterval',
#  'Day',
#  'Month',
#  'Year',
#  'DayOfYear',
#  'WeekOfYear']

# %%
# Dropping the id coloumn since it has shown its non functionality.
test_store.drop(['Id'], axis=1, inplace=True)
test_store.sample(2)
# Out:
#             Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday  \
# Date
# 2015-09-11    457          5   1.0      0            0              1
# 2015-08-12    776          3   1.0      0            0              0
#
#            StoreType Assortment  CompetitionDistance  \
# Date
# 2015-09-11         d          c              13140.0
# 2015-08-12         c          a                700.0
#
#             CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# Date
# 2015-09-11                        NaN                       NaN       1
# 2015-08-12                        4.0                    2009.0       1
#
#             Promo2SinceWeek  Promo2SinceYear    PromoInterval  Day  Month  \
# Date
# 2015-09-11             31.0           2013.0  Jan,Apr,Jul,Oct   11      9
# 2015-08-12             14.0           2011.0  Jan,Apr,Jul,Oct   12      8
#
#             Year  DayOfYear  WeekOfYear
# Date
# 2015-09-11  2015        254          37
# ...

# %%
test_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 41088 entries, 2015-08-01 to 2015-09-17
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      41088 non-null  int64
#  1   DayOfWeek                  41088 non-null  int64
#  2   Open                       41077 non-null  float64
#  3   Promo                      41088 non-null  int64
#  4   StateHoliday               41088 non-null  object
#  5   SchoolHoliday              41088 non-null  int64
#  6   StoreType                  41088 non-null  object
#  7   Assortment                 41088 non-null  object
#  8   CompetitionDistance        40992 non-null  float64
#  9   CompetitionOpenSinceMonth  25872 non-null  float64
#  10  CompetitionOpenSinceYear   25872 non-null  float64
#  11  Promo2                     41088 non-null  int64
#  12  Promo2SinceWeek            23856 non-null  float64
# ...

# %%
# Column names
train_store.columns.tolist()
# Out:
# ['Store',
#  'DayOfWeek',
#  'Sales',
#  'Customers',
#  'Open',
#  'Promo',
#  'StateHoliday',
#  'SchoolHoliday',
#  'StoreType',
#  'Assortment',
#  'CompetitionDistance',
#  'CompetitionOpenSinceMonth',
#  'CompetitionOpenSinceYear',
#  'Promo2',
#  'Promo2SinceWeek',
#  'Promo2SinceYear',
#  'PromoInterval',
#  'Day',
#  'Month',
#  'Year',
#  'DayOfYear',
#  'WeekOfYear']

# %%
train_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1017209 entries, 2013-01-01 to 2015-07-31
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Sales                      1017209 non-null  int64
#  3   Customers                  1017209 non-null  int64
#  4   Open                       1017209 non-null  int64
#  5   Promo                      1017209 non-null  int64
#  6   StateHoliday               1017209 non-null  object
#  7   SchoolHoliday              1017209 non-null  int64
#  8   StoreType                  1017209 non-null  object
#  9   Assortment                 1017209 non-null  object
#  10  CompetitionDistance        1014567 non-null  float64
#  11  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### --> Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

# generate 1000 data points randomly drawn from an exponential distribution
original_data = pd.DataFrame(np.random.exponential(200, size=2000))

original_data.sample(5)
# Out:
#                0
# 1191  100.993753
# 1396  403.244502
# 383   166.065625
# 887   231.345777
# 518   273.732217

# %%
original_data[0].min(), original_data[0].max()
# Out:
# (0.13780655378006088, 1286.809745708483)

# %%
count, bins, ignored = plt.hist(original_data, 14)
plt.show()

# %%
# mix-max scale the data between 0 and 1
def scaler(df):
    scaled_data = minmax_scaler.fit_transform(df)

    # plot both together to compare
    fig, ax = plt.subplots(1,2, figsize=(10, 6))
    sns.histplot(original_data, ax=ax[0])
    ax[0].set_title("Original Data")
    sns.histplot(scaled_data, ax=ax[1])
    ax[1].set_title("Scaled data")
    
scaler(original_data)

# %% [markdown]
# ### --> Normalization

# %%
from sklearn.preprocessing import Normalizer

def normalizer(df):
    norm = Normalizer()
    # normalize the exponential data with boxcox
    normalized_data = norm.fit_transform(df)

    # plot both together to compare
    fig, ax=plt.subplots(1,2, figsize=(10, 6))
    sns.histplot(df, ax=ax[0])
    ax[0].set_title("Original Data")
    sns.histplot(normalized_data[0], ax=ax[1])
    ax[1].set_title("Normalized data")

normalizer(original_data)

# %% [markdown]
# ### EDA Questions

# %% [markdown]
# ### Plotting Functions

# %%
def plot_hist(df:pd.DataFrame, column:str, color:str)->None:
    # plt.figure(figsize=(15, 10))
    # fig, ax = plt.subplots(1, figsize=(12, 7))
    sns.displot(data=df, x=column, color=color, kde=True, height=7, aspect=2)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()

def plot_count(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_bar(df:pd.DataFrame, x_col:str, y_col:str, title:str, xlabel:str, ylabel:str)->None:
    plt.figure(figsize=(12, 7))
    sns.barplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.show()

def plot_heatmap(df:pd.DataFrame, title:str, cbar=False)->None:
    plt.figure(figsize=(12, 7))
    sns.heatmap(df, annot=True, cmap='viridis', vmin=0, vmax=1, fmt='.2f', linewidths=.7, cbar=cbar )
    plt.title(title, size=18, fontweight='bold')
    plt.show()

def plot_box(df:pd.DataFrame, x_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.show()

def plot_box_multi(df:pd.DataFrame, x_col:str, y_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()

def plot_scatter(df: pd.DataFrame, x_col: str, y_col: str, title: str, hue: str, style: str) -> None:
    plt.figure(figsize=(12, 7))
    sns.scatterplot(data = df, x=x_col, y=y_col, hue=hue, style=style)
    plt.title(title, size=20)
    plt.xticks(fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()

# %% [markdown]
# #### 1. Check for distribution in both training and test sets - are the promotions distributed similarly between these two groups?

# %%
plot_hist(test_store, "Promo", "blue")

# %%
plot_hist(train_store, "Promo", "blue")

# %% [markdown]
# From the graphs we see that there is a similar distribution in the promotions.

# %%
plot_hist(test_store, "Promo2", "red")

# %%
plot_hist(train_store, "Promo2", "red")

# %% [markdown]
# There is a clear distribution in the test data for Promo2. While the distribution in the train data is very similar.

# %% [markdown]
# #### 2. Check & compare sales behavior before, during and after holidays

# %%
# comparing holiday day sales with non Holiday ones

holidays = train_store.loc[train_store["StateHoliday"] != 'No Holiday']

titles = ['Sales: Holidays vs. ordinary days', 'Sales during State Holidays']
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(12,4))
sns.barplot(x="StateHoliday", y="Sales", data=train_store, ax=axis1).set_title(titles[0])
sns.barplot(x="StateHoliday", y="Sales", data=holidays, ax=axis2).set_title(titles[1])
plt.show()

# %% [markdown]
# The sales were more on no holiday while comparing with ordinary days

# %% [markdown]
# #### 3. Find out any seasonal (Christmas, Easter etc) purchase behaviours,

# %%
train_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
# Sales StateHoliday
plt.figure(figsize=(12, 8))
plt.scatter(train_store["StateHoliday"],train_store["Sales"])
plt.plot()
# Out:
# []

# %% [markdown]
# Sales are higher on ordinary days as compared to the holidays

# %%
#Sales_Open
sns.set()
plt.hist(train_store[train_store['Open'] == 1].Sales, color='green', alpha=0.3, label = 'YES')
plt.hist(train_store[train_store['Open'] == 0].Sales, color='red', alpha=0.3, label = 'NO')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# There being no red bars, it means that the stores make no sales when they are closed.

# %% [markdown]
# ### 4. What can you say about the correlation between sales and number of customers?

# %%
# Sales vs Customers
from pandas.plotting import scatter_matrix
attributes = ["Sales", "Customers"]
scatter_matrix(train_df[attributes], alpha=0.1);

# %% [markdown]
# The sales and customers are highly correlated.

# %% [markdown]
# #### 5. How does promo affect sales? Are the promos attracting more customers? How does it affect already existing customers?

# %%
#Sales_Promo
sns.set()
plt.hist(train_store[train_store['Promo'] == 1].Sales, color='green', alpha=0.3, label = 'YES')
plt.hist(train_store[train_store['Promo'] == 0].Sales, color='red', alpha=0.3, label = 'NO')
plt.legend()
plt.plot()
# Out:
# []

# %%
#Sales_Promo2
sns.set()
plt.hist(train_store[train_store['Promo2'] == 1].Sales, color='green', alpha=0.3, label = 'YES')
plt.hist(train_store[train_store['Promo2'] == 0].Sales, color='red', alpha=0.3, label = 'NO')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #### 6. Could the promos be deployed in more effective ways? Which stores should promos be deployed in?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(train_store['Store'],train_df['Sales'], alpha=0.1);
plt.plot()
# Out:
# []

# %% [markdown]
# #### 7. Trends of customer behavior during store open and closing times

# %%
#Sales_Open
sns.set()
plt.hist(train_store[train_store['Open'] == 1].Sales, color='green', alpha=0.3, label = 'YES')
plt.hist(train_store[train_store['Open'] == 0].Sales, color='red', alpha=0.3, label = 'NO')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #### 8. Which stores are opened on all weekdays? How does that affect their sales on weekends?

# %%
train_store['Store'].unique()
# Out:
# array([   1,    2,    3, ..., 1113, 1114, 1115], dtype=int64)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,4))

sns.barplot(x='DayOfWeek', y='Store', data=train_store, order=[1,2,3,4,5,6,7], ax=axis1)
sns.barplot(x='DayOfWeek', y='Customers', data=train_store, order=[1,2,3,4,5,6,7], ax=axis2)
# Out:
# <AxesSubplot:xlabel='DayOfWeek', ylabel='Customers'>

# %% [markdown]
# #### 9. Check how the assortment type affects sales

# %%
#Sales_Assortment
sns.set()
plt.hist(train_store[train_store['Assortment'] == 'a'].Sales, color='green', alpha=0.3, label = 'a')
plt.hist(train_store[train_store['Assortment'] == 'b'].Sales, color='red', alpha=0.3, label = 'b')
plt.hist(train_store[train_store['Assortment'] == 'c'].Sales, color='yellow', alpha=0.3, label = 'c')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# Stores with 'b' assortment type by do not make much sales as compared to the others.

# %% [markdown]
# #### 10. How does the distance to the next competitor affect sales? What if the store and its competitors all happen to be in city centres, does the distance matter in that case?

# %%
plt.figure(figsize=(12, 8))
plt.scatter(train_store['CompetitionDistance'],train_store['Sales'], alpha=0.1);
plt.plot()
# Out:
# []

# %% [markdown]
# The further the distance between each store the lower the sales.

# %% [markdown]
# #### 11. How does the opening or reopening of new competitors affect stores? Check for stores with NA as competitor distance but later on has values for competitor distance
